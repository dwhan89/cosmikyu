# %%
from cosmikyu import visualization as covis
from cosmikyu import gan, config
import numpy as np
import os
import torchvision.transforms as transforms
from torchvision import datasets
from torchvision.utils import save_image
import matplotlib.pyplot as plt
import torch
import mlflow
import torchsummary

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
shape = (5,128,128)
latent_dim = 64

# %%
print("====cosmogan_wgp======")
cosmogan_wgp = gan.COSMOGAN_WGP("test", shape, latent_dim, cuda=False, ngpu=4)
torchsummary.summary(cosmogan_wgp.discriminator.cuda(), shape)
torchsummary.summary(cosmogan_wgp.generator.cuda(), (latent_dim,))
del cosmogan_wgp
# Out:
# ====cosmogan_wgp======
# [WARNING] You have a CUDA device. You probably want to run with CUDA enabled
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 64, 64]           8,064
#          LeakyReLU-2           [-1, 64, 64, 64]               0
#             Conv2d-3          [-1, 128, 32, 32]         204,928
#          LeakyReLU-4          [-1, 128, 32, 32]               0
#             Conv2d-5          [-1, 256, 16, 16]         819,456
#          LeakyReLU-6          [-1, 256, 16, 16]               0
#             Conv2d-7            [-1, 512, 8, 8]       3,277,312
#          LeakyReLU-8            [-1, 512, 8, 8]               0
#            Reshape-9                [-1, 32768]               0
#            Linear-10                    [-1, 1]          32,769
# ...
# Total params: 4,342,529
# Trainable params: 4,342,529
# Non-trainable params: 0
# ...

# %%
print("====cosmogan======")
cosmogan = gan.COSMOGAN("test", shape, latent_dim, cuda=False, ngpu=4)
torchsummary.summary(cosmogan.discriminator.cuda(), shape)
torchsummary.summary(cosmogan.generator.cuda(), (latent_dim,))
del cosmogan
# Out:
# ====dcgan======
# [WARNING] You have a CUDA device. You probably want to run with CUDA enabled
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 64, 64]           8,064
#          LeakyReLU-2           [-1, 64, 64, 64]               0
#             Conv2d-3          [-1, 128, 32, 32]         204,928
#        BatchNorm2d-4          [-1, 128, 32, 32]             256
#          LeakyReLU-5          [-1, 128, 32, 32]               0
#             Conv2d-6          [-1, 256, 16, 16]         819,456
#        BatchNorm2d-7          [-1, 256, 16, 16]             512
#          LeakyReLU-8          [-1, 256, 16, 16]               0
#             Conv2d-9            [-1, 512, 8, 8]       3,277,312
#       BatchNorm2d-10            [-1, 512, 8, 8]           1,024
#         LeakyReLU-11            [-1, 512, 8, 8]               0
# ...

# %%
print("====wgan_gp======")

wgan_gp = gan.WGAN_GP("test", shape, latent_dim, cuda=False, ngpu=4)
torchsummary.summary(wgan_gp.discriminator.cuda(), shape)
torchsummary.summary(wgan_gp.generator.cuda(), (latent_dim,))
del wgan_gp

print("====wgan======")

wgan = gan.WGAN("test", shape, latent_dim, cuda=False, ngpu=4)
torchsummary.summary(wgan.discriminator.cuda(), shape)
torchsummary.summary(wgan.generator.cuda(), (latent_dim,))
del wgan
# Out:
# ====wgan_gp======
# [WARNING] You have a CUDA device. You probably want to run with CUDA enabled
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Linear-1                  [-1, 512]      41,943,552
#          LeakyReLU-2                  [-1, 512]               0
#             Linear-3                  [-1, 256]         131,328
#          LeakyReLU-4                  [-1, 256]               0
#             Linear-5                    [-1, 1]             257
# ...
# Total params: 42,075,137
# Trainable params: 42,075,137
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.31
# Forward/backward pass size (MB): 0.01
# Params size (MB): 160.50
# Estimated Total Size (MB): 160.83
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# ...
